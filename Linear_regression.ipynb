# %% [markdown]
# # Программа для предсказания показателей финансирования жилищных объектов( на 7 лет вперед)
# Программа извлекает данные из базы данных, использует линейную регрессию для предсказания каждого отдельного показателя и загружает предсказания, присваивая каждому предсказанному значению статус - 'Прогноз'.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine, text

# %%
class predicting:
    def __init__ (self):
        a = 0

    #Данные функции были созданы для того, чтобы преобразовать изначальный файл, который был предоставлен, в более удобный формат.   
    
    # В последующих версиях, она необязательна для использования, поскольку модель будет извлекать данные прямо из базы данных.
    def preparation(self):        
        df = pd.read_excel(r"C:\Users\user\OneDrive\Рабочий стол\Data Science\Стажировка\Линейная регрессия\Данные_по_рынку_недвижимости_powerbi_формат.xlsx", sheet_name = 'Сводная файл')
        df = df.drop("№", axis = 1)
        df = df[df['Статус'] == 'Факт']
        df = df.dropna()
        df.rename(columns={'Область/Город': 'Регион'}, inplace=True)
        df.rename(columns={'Название информации': 'Информация'}, inplace=True)
        return df

    #Загружает преобразованные данные в таблицу
    def inserting(df):
        engine = create_engine("mysql+mysqlconnector://root:@127.0.0.1:3306/данные_по_рынку_недвижимости", echo=True)
        conn = engine.connect()
        #Вручную создаем таблицы, чтобы правильно задать типы данных столбцов
        conn.execute(text("""                
        CREATE TABLE IF NOT EXISTS Data(
            `№` int auto_increment,
            `Область/Город` TEXT, 
            Год INT, 
            `Название информации` TEXT,
            Значение FLOAT, 
            Статус TEXT       
            )
        """))
        conn.commit()
        df.to_sql('data', engine, if_exists = 'append',  index=False)


#-----------------------------------------------------------------------------------------------------------
    

    #Простая функция, которая извлекат данные из базы данных, благодаря SQLalchemy
    def extract_data(self):
        engine = create_engine("mysql+mysqlconnector://root:@127.0.0.1:3306/данные_по_рынку_недвижимости", echo=True)
        conn = engine.connect()
        df = pd.read_sql('data', con = conn)
        return df
        
    
    def linear_regression(self, df ):
        indicators = df['Информация'].unique()
        regions = df['Регион'].unique()
        pv_df = pd.pivot_table(df, values = "Значение", index = ["Регион", "Год"], columns = "Информация") # Создаем сводную таблицу, чтобы легко доставать данные по регионам и годам
        pv_df = pv_df.interpolate(method = 'linear') # Заполнение пропусков, методом интерполяции
        pv_df = pv_df.dropna() #Некоторые ряды имеют слишком много пропусков и их уже приходится удалять
        print(pv_df)
        print('='*50)
        region_tables = {}
        for region in regions:
            try:
                region_data = pv_df.xs(region, level='Регион') # Достаем данные регионов из мультииндекса
                region_tables[region] = region_data
            except KeyError:
                print(f"Нет данных для региона: {region}")
                continue
        forecast_years = [2025, 2026, 2027, 2028, 2029, 2030, 2031]
        forecast_df = pd.DataFrame()
        for region in regions:
            region_data = pv_df.xs(region, level='Регион')
            for indicator in indicators:
                 X = region_data.index.get_level_values('Год').values.reshape(-1, 1)
                 y = region_data[indicator].values
         
                 model = LinearRegression()
                 model.fit(X, y)
         
                 future_years = np.array(forecast_years).reshape(-1, 1)
                 future_predictions = model.predict(future_years)

                 for year, pred in zip(forecast_years, future_predictions):
                     forecast_df = pd.concat([
                        forecast_df,
                        pd.DataFrame({
                             'Регион': [region],
                             'Год': [year],
                             'Информация': [indicator],
                             'Значение': [pred],
                             'Статус': 'Прогноз'
                         })
                     ], ignore_index=True)
        return forecast_df

    # Функция для визуализации всех предсказаний, вместе с настоящими данными 
    def visuals(self, df, forecast_df ):
        indicators = df['Информация'].unique()
        regions = df['Регион'].unique()
        final_df = pd.concat([forecast_df, df])
        pv_df1 = pd.pivot_table(final_df, values = "Значение", index = ["Регион", "Год"], columns = "Информация")

        for region in regions:
            region_data = pv_df1.xs(region, level='Регион')
            for indicator in indicators:
                plt.plot(region_data.index.get_level_values('Год').values.reshape(-1, 1), region_data[indicator].values, 
                    marker='o', 
                    linewidth=2,
                    markersize=8,
                    label=indicator)
                plt.title(region, fontsize=16, pad=20)
                plt.xlabel('Год', fontsize=12)
                plt.ylabel(indicator, fontsize=12)
                plt.xticks(rotation=45, fontsize=10)
                plt.yticks(fontsize=10)
                plt.grid(True, alpha=0.3)


                plt.tight_layout()
                plt.show()

    #Функция, которая позволяет вставить данные предсказаний обратно в базу данных 
    def inserting_predictions(self, forecast_df):
        engine = create_engine("mysql+mysqlconnector://root:@127.0.0.1:3306/данные_по_рынку_недвижимости", echo=True)
        conn = engine.connect()
        forecast_df.to_sql('data', engine, if_exists = 'append',  index=False)

# %%
pre = predicting()
df = pre.extract_data()
forecast_df = pre.linear_regression(df)
# Out:
# 2025-06-27 10:21:12,628 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-06-27 10:21:12,629 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:21:12,640 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-06-27 10:21:12,641 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:21:12,647 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-06-27 10:21:12,648 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:21:12,661 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-27 10:21:12,667 INFO sqlalchemy.engine.Engine DESCRIBE `данные_по_рынку_недвижимости`.`data`
# 2025-06-27 10:21:12,667 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:21:12,763 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `данные_по_рынку_недвижимости`
# 2025-06-27 10:21:12,766 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:21:12,778 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `данные_по_рынку_недвижимости`
# 2025-06-27 10:21:12,780 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:21:12,820 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `data`
# 2025-06-27 10:21:12,822 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:21:12,836 INFO sqlalchemy.engine.Engine SELECT data.`Регион`, data.`Год`, data.`Информация`, data.`Значение`, data.`Статус`
# FROM data
# 2025-06-27 10:21:12,843 INFO sqlalchemy.engine.Engine [generated in 0.00258s] {}
# Информация       Удельный вес жилищного фонда оборудованного водоснабжением (%)  \
# Регион    Год
# Абайская  2022                                           100.0000
#           2023                                            99.9933
#           2024                                            99.9924
#           2025                                            99.9876
#           2026                                            99.9838
# ...                                                           ...
# г.Шымкент 2027                                            99.9967
#           2028                                            99.9963
#           2029                                            99.9959
#           2030                                            99.9954
#           2031                                            99.9950
#
# Информация      Количество жилых домов (ед.)  Объем жилищного фонда (кв.м.)  \
# Регион    Год
# Абайская  2022                      104800.0                     11932400.0
#           2023                      105316.0                     12146900.0
#           2024                      105732.0                     12312200.0
#           2025                      106215.0                     12510300.0
#           2026                      106681.0                     12700200.0
# ...                                      ...                            ...
# г.Шымкент 2027                      159500.0                     26509100.0
#           2028                      162944.0                     27451600.0
#           2029                      166388.0                     28394100.0
#           2030                      169832.0                     29336600.0
#           2031                      173276.0                     30279075.0
#
# Информация      Объем жилищного фонда в городской местности (кв.м.)  \
# Регион    Год
# Абайская  2022                                          7240700.0
#           2023                                          7420070.0
#           2024                                          7584100.0
#           2025                                          7758360.0
#           2026                                          7930060.0
# ...                                                           ...
# г.Шымкент 2027                                         26509100.0
#           2028                                         27451600.0
#           2029                                         28394100.0
#           2030                                         29336600.0
#           2031                                         30279075.0
#
# Информация      Объем жилищного фонда в сельской местности (кв.м.)  \
# Регион    Год
# Абайская  2022                                          4691800.0
#           2023                                          4726870.0
#           2024                                          4728100.0
#           2025                                          4751890.0
#           2026                                          4770040.0
# ...                                                           ...
# г.Шымкент 2027                                                0.0
#           2028                                                0.0
#           2029                                                0.0
#           2030                                                0.0
#           2031                                                0.0
#
# Информация      Площадь введенного в эксплуатацию жилья (кв.м.)  \
# Регион    Год
# Абайская  2022                                         340531.0
#           2023                                         362654.0
#           2024                                         363246.0
#           2025                                         378192.0
#           2026                                         389550.0
# ...                                                         ...
# г.Шымкент 2027                                        1805830.0
#           2028                                        1960410.0
#           2029                                        2114990.0
#           2030                                        2269560.0
#           2031                                        2424140.0
#
# Информация      Среднегодовая численность населения РК (чел.)  \
# Регион    Год
# Абайская  2022                                       611047.0
#           2023                                       607556.0
#           2024                                       602882.0
#           2025                                       598997.0
#           2026                                       594914.0
# ...                                                       ...
# г.Шымкент 2027                                      1403820.0
#           2028                                      1451840.0
#           2029                                      1499870.0
#           2030                                      1547890.0
#           2031                                      1595910.0
#
# Информация      Удельный вес жилищного фонда оборудованного газоснабжением (%)  \
# Регион    Год
# Абайская  2022                                           76.95000
#           2023                                           80.90000
#           2024                                           84.85000
#           2025                                           88.80000
#           2026                                           92.75000
# ...                                                           ...
# г.Шымкент 2027                                          100.18075
#           2028                                          100.25450
#           2029                                          100.32875
#           2030                                          100.40275
#           2031                                          100.47650
#
# Информация      Удельный вес жилищного фонда оборудованного душом или ванной (%)  \
# Регион    Год
# Абайская  2022                                          27.400000
#           2023                                          28.193200
#           2024                                          28.652800
#           2025                                          29.334800
#           2026                                          29.961200
# ...                                                           ...
# г.Шымкент 2027                                          54.907225
#           2028                                          59.247800
#           2029                                          63.588300
#           2030                                          67.928800
#           2031                                          72.269400
#
# Информация      Удельный вес жилищного фонда оборудованного канализацией (%)  \
# Регион    Год
# Абайская  2022                                            57.7000
#           2023                                            60.2551
#           2024                                            62.0607
#           2025                                            64.3659
#           2026                                            66.5463
# ...                                                           ...
# г.Шымкент 2027                                            91.6633
#           2028                                            93.4096
#           2029                                            95.1560
#           2030                                            96.9024
#           2031                                            98.6487
#
# Информация      Удельный вес жилищного фонда оборудованного центральным горячим водоснабжением (%)  \
# Регион    Год
# Абайская  2022                                           29.20000
#           2023                                           29.83060
#           2024                                           30.08090
#           2025                                           30.58470
#           2026                                           31.02520
# ...                                                           ...
# г.Шымкент 2027                                            5.98565
#           2028                                            6.00430
#           2029                                            6.02294
#           2030                                            6.04158
#           2031                                            6.06023
#
# Информация      Удельный вес жилищного фонда оборудованного центральным отоплением (%)
# Регион    Год
# Абайская  2022                                            36.4000
#           2023                                            37.0574
#           2024                                            37.6227
#           2025                                            38.2494
#           2026                                            38.8608
# ...                                                           ...
# г.Шымкент 2027                                            35.5687
#           2028                                            36.5143
#           2029                                            37.4598
#           2030                                            38.4054
#           2031                                            39.3510
#
# [596 rows x 12 columns]
# ==================================================

# %%
# pre.visuals(df, forecast_df) 
# Программе нужно визуализировать каждый индикатор каждого региона по отдельности, поэтому я не буду ее запускать
# Вы можете сами запустить, если хотите взглянуть на предсказания и сравнить их.

# %%
pre.inserting_predictions(forecast_df)
# Out:
# 2025-06-27 10:23:04,188 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-06-27 10:23:04,191 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:23:04,198 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-06-27 10:23:04,198 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:23:04,204 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-06-27 10:23:04,204 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:23:04,219 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-27 10:23:04,230 INFO sqlalchemy.engine.Engine DESCRIBE `данные_по_рынку_недвижимости`.`data`
# 2025-06-27 10:23:04,234 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-27 10:23:04,389 INFO sqlalchemy.engine.Engine INSERT INTO data (`Регион`, `Год`, `Информация`, `Значение`, `Статус`) VALUES (%(Регион)s, %(Год)s, %(Информация)s, %(Значение)s, %(Статус)s)
# 2025-06-27 10:23:04,389 INFO sqlalchemy.engine.Engine [generated in 0.02382s] [{'Регион': 'Акмолинская', 'Год': 2025, 'Информация': 'Объем жилищного фонда (кв.м.)', 'Значение': 18829507.983870983, 'Статус': 'Прогноз'}, {'Регион': 'Акмолинская', 'Год': 2026, 'Информация': 'Объем жилищного фонда (кв.м.)', 'Значение': 19109086.290322542, 'Статус': 'Прогноз'}, {'Регион': 'Акмолинская', 'Год': 2027, 'Информация': 'Объем жилищного фонда (кв.м.)', 'Значение': 19388664.59677422, 'Статус': 'Прогноз'}, {'Регион': 'Акмолинская', 'Год': 2028, 'Информация': 'Объем жилищного фонда (кв.м.)', 'Значение': 19668242.90322578, 'Статус': 'Прогноз'}, {'Регион': 'Акмолинская', 'Год': 2029, 'Информация': 'Объем жилищного фонда (кв.м.)', 'Значение': 19947821.20967734, 'Статус': 'Прогноз'}, {'Регион': 'Акмолинская', 'Год': 2030, 'Информация': 'Объем жилищного фонда (кв.м.)', 'Значение': 20227399.516129017, 'Статус': 'Прогноз'}, {'Регион': 'Акмолинская', 'Год': 2031, 'Информация': 'Объем жилищного фонда (кв.м.)', 'Значение': 20506977.822580576, 'Статус': 'Прогноз'}, {'Регион': 'Акмолинская', 'Год': 2025, 'Информация': 'Объем жилищного фонда в городской местности (кв.м.)', 'Значение': 9112255.685483873, 'Статус': 'Прогноз'}  ... displaying 10 of 1932 total bound parameter sets ...  {'Регион': 'Республика Казахстан ', 'Год': 2030, 'Информация': 'Среднегодовая численность населения РК (чел.)', 'Значение': 21801298.888888896, 'Статус': 'Прогноз'}, {'Регион': 'Республика Казахстан ', 'Год': 2031, 'Информация': 'Среднегодовая численность населения РК (чел.)', 'Значение': 22053835.555555582, 'Статус': 'Прогноз'}]
# 2025-06-27 10:23:04,629 INFO sqlalchemy.engine.Engine COMMIT
